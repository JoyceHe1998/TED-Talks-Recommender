# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.cluster import MiniBatchKMeans, KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
data = pd.read_json('./tedData.json')
data
# Out:
#               id                                              title  \
# 0    UfWh3OHYbEM             The language of being human | Poet Ali
# 1    TntLjM_uBT0  Crisis support for the world, one text away | ...
# 2    8bj0GR34XWc  A global pandemic calls for global solutions |...
# 3    bNmRr-BYnxA  How to shift your mindset and choose your futu...
# 4    zpn6MCmoK0g         An ode to living on Earth | Oliver Jeffers
# ..           ...                                                ...
# 644  waVUm5bhLbg          Empathy is not endorsement | Dylan Marron
# 645  1XvLEhZIAVk        'RainMakers' | Qudus Onikeku and The QTribe
# 646  TfKpvpxdNz8  What I've learned about parenting as a stay-at...
# 647  yF4MgSh7VO4  How work kept me going during my cancer treatm...
# 648  JoUZ929qoLk  A woman's fury holds lifetimes of wisdom | Tra...
#
#                                                   tags
# 0    poetry, language, humanity, emotions, culture,...
# ...

# %%
tfidf = TfidfVectorizer(
    min_df = 5,
    max_df = 0.95,
    max_features = None,
    stop_words = 'english'
)
tfidf.fit(data.tags)
text = tfidf.transform(data.tags)

# %%
text
# Out:
# <649x205 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4281 stored elements in Compressed Sparse Row format>

# %%
def find_optimal_clusters(data, max_k):
    iters = range(2, max_k+1, 2)
    
    sse = []
    for k in iters:
        sse.append(MiniBatchKMeans(n_clusters=k, init_size=None, batch_size=2, random_state=20).fit(data).inertia_)
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='o')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')
    
find_optimal_clusters(text, 50)
# Out:
# Fit 2 clusters
# Fit 4 clusters
# Fit 6 clusters
# C:\Users\Xueqi Zeng\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=6 should be larger than k=8. Setting it to 3*k
#   init_size=init_size)
# C:\Users\Xueqi Zeng\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=6 should be larger than k=8. Setting it to 3*k
#   init_size=init_size)
# C:\Users\Xueqi Zeng\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=6 should be larger than k=8. Setting it to 3*k
#   init_size=init_size)
# Fit 8 clusters
# Fit 10 clusters
# C:\Users\Xueqi Zeng\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=6 should be larger than k=10. Setting it to 3*k
#   init_size=init_size)
# C:\Users\Xueqi Zeng\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1576: RuntimeWarning: init_size=6 should be larger than k=10. Setting it to 3*k
#   init_size=init_size)
# ...

# %%
# clusters = MiniBatchKMeans(n_clusters=100, init_size=None, batch_size=4, random_state=20).fit_predict(text)
clusters = KMeans(n_clusters=10).fit_predict(text)

clusters

data1 = data.copy()
data1['cluster#'] = clusters
import pandas
pandas.set_option('display.max_columns',None)
pandas.set_option('display.max_rows',None)
pandas.set_option('display.max_colwidth', None)
data1 = data1.sort_values('cluster#')
data1
# Out:
#               id  \
# 565  qaIghx4QRN4
# 276  Ta8KBJ4BTNg
# 584  rfi3w9Bzwik
# 156  2UZKME9WP9M
# 147  4zLmWpMDY8Q
# 165  2GhJ6CTDEoM
# 533  uv5-hIif7BQ
# 16   wGGmzeCT8gU
# 286  oBdzOIzwtng
# 136  s7QPgarhiWg
# 333  uyMtsyzXWd4
# 347  -jNlpGLpelg
# 296  88d-58tWhGs
# 302  aVOJA8qI7oo
# 480  L7X17aash2s
# 125  LQMLFryA_7k
# 56   y8ohTeRKVqs
# 359  XY6aAPhs0tE
# 362  7uRPPaYuu44
# 224  oH-pbEqdJTQ
# 263  PUW89NpDYJw
# 197  fh5KLfd9Km8
# 428  bLAw7yF0YBc
# 58   f8c3TzQtD4k
# 343  YkYdxjaqt58
# 607  1w3NXBXdY5c
# 583  WhpAYw9kCt8
# 47   kXGuWtR5ulg
# 326  ONs9FCY74p0
# 282  zELJMIQawys
# 93   uTfaua3X0RU
# 98   eZ5MM28abKo
# 559  l--QYXCecew
# 101  6pSMgmL7vF0
# 573  6ElobAhlQo0
# 128  yfLp_vueUxY
# 107  i5vZkaUk528
# 123  ir5yzW0yIk0
# 497  Euegk8-WjoQ
# 563  TSomH3iGgYY
# 113  -3y6_7_5PcQ
# 155  lSPxeA6Z_m4
# 613  -nKdufEaL8k
# 111  ysRvYxznrq4
# 526  KyVSuI6JyOs
# 487  dgJsm8gDLK0
# 18   qWwEoD68gwQ
# 516  xgBnYr0_FRk
# 628  zfbigT9I0Qg
# 385  jr5mTwfFh00
# 483  b2Jv8vC-m3g
# ...

# %%
def plot_tsne_pca(data, labels):
    max_label = max(labels)
#     max_items = np.random.choice(range(data.shape[0]), size=3000, replace=False)
    max_items = np.random.choice(range(data.shape[0]), size=649, replace=False)
        
    pca = PCA().fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA().fit_transform(data[max_items,:].todense()))
    
#     idx = np.random.choice(range(pca.shape[0]), size=300, replace=False)
    idx = np.random.choice(range(pca.shape[0]), size=649, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %%
from wordcloud import WordCloud

# fig, ax = plt.subplots(10, sharex=True, figsize=(15,10*5))
# plt.rcParams['axes.grid'] = False

def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        words = ','.join([labels[t] for t in np.argsort(r)[-n_terms:]])
        print(words)
        
        wordcloud = WordCloud(max_font_size=55, collocations=False, background_color='white').generate(words) # colormap='Reds',
#         ax[i].imshow(wordcloud, interpolation='bilinear')
#         ax[i].set_title('Cluster {}'.format(i), fontsize=20)
#         ax[i].axis('off')
        plt.figure(1,figsize=(10, 10))
        plt.imshow(wordcloud)
        plt.axis('off')
#         plt.title('Cluster {}'.format(i))
        plt.savefig('Cluster {}.png'.format(i))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(),15)
# Out:
# Cluster 0
# visualizations,fellows,nature,technology,discovery,science,exploration,nasa,solar,planets,astronomy,cosmos,physics,universe,space
#
# Cluster 1
# issues,human,illness,ted,body,technology,society,change,innovation,social,disease,medicine,care,public,health
#
# Cluster 2
# law,policy,democracy,history,culture,justice,states,united,activism,humanity,government,community,society,change,social
#
# Cluster 3
# setting,change,writing,identity,motivation,relationships,work,life,society,potential,humanity,communication,success,growth,personal
#
# Cluster 4
# neuroscience,humanity,future,invention,technology,biotech,brain,medicine,science,human,health,body,biology,research,medical
#
# Cluster 5
# business,growth,personal,success,happiness,tedx,change,social,money,self,leadership,life,way,balance,work
#
# Cluster 6
# ted,history,culture,sustainability,environment,innovation,performance,humanity,future,nature,creativity,design,science,art,technology
#
# Cluster 7
# ...
