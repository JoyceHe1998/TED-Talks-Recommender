# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
data = pd.read_json('./tedData.json')
data
# Out:
#               id                                               tags  \
# 0    UfWh3OHYbEM  poetry, language, humanity, emotions, culture,...
# 1    TntLjM_uBT0  technology, software, communication, community...
# 2    8bj0GR34XWc  global issues, science, collaboration, virus, ...
# 3    bNmRr-BYnxA  climate change, environment, global issues, ch...
# 4    zpn6MCmoK0g  creativity, art, love, community, poetry, pers...
# 5    FVUkKKc3Vvk  life, society, immigration, humanity, self, pe...
# 6    YgAuFqEs6yk  family, parenting, communication, children, re...
# 7    sNQfoYm3WI0
# 8    JWRqI2ZRHWQ  music, live music, performance, jacob collier,...
# 9    eaCrsBtiYA4
# 10   OMDVTZ-ycaY  humanity, technology, curiosity, science, expl...
# 11   ldKtWp7jlHI  ted connects, coronavirus, pandemic, economics...
# 12   f0jETLKTW7w  ted connects, india, economics, poverty, coron...
# 13   yrxYhv2O3wU
# 14   CBSkV8sgUQ0  ted connects, activism, technology, coronaviru...
# 15   ppjXgm4t9ko  molecular biology, crispr, biology, animation,...
# 16   wGGmzeCT8gU  planets, space, chemistry, exploration, discov...
# 17   2g8BeujckJY  relationships, love, empathy, communication, h...
# 18   qWwEoD68gwQ  science, health care, medicine, public health,...
# 19   f4xu7w6Vf0U  coronavirus pandemic virus software ted connec...
# 20   oNBvC25bxQU
# 21   bW941OpsnMM  social change, activism, human rights, communi...
# 22   GFpciGYBELo  sleep, medicine, health, pandemic, biology, co...
# 23   kmbui1xF8DE  design, society, identity, social change, comm...
# 24   y4vurv9usYA  autism, social change, autism spectrum, disord...
# 25   CoQuaDKV3xk              coronavirus, history, pandemic, virus
# 26   wvJTbegktKc  climate change, science, environment, nature, ...
# 27   IyuiVTsIctg
# 28   quDwQ7W9eKc  law, justice system, society, inequality, pris...
# 29   i_1_J-T-XYQ  humanity, coronavirus, communication, ted conn...
# ..           ...                                                ...
# 619  ARb2UfDgSHQ  aging, happiness, comedy, humanity, illness, h...
# 620  dO1LxQEoGLc        energy, pollution, mining, medical research
# 621  _tewedUBhAo  community, humanity, society, identity, immigr...
# 622  A_u2WFTfbcg  creativity, evolution, happiness, humanity, ev...
# 623  TZNOrZIdct8                          live music, singer, cello
# 624  xHHb7R3kx40  biotech, social change, future, history, leade...
# 625  hQltlSDNmd0  communication, activism, women, society, ted f...
# 626  SO7pX6ojJQ0                                       money, trust
# 627  3P-2dcS19fk  social change, society, government, failure, d...
# 628  zfbigT9I0Qg  health, health care, war, medicine, violence, ...
# 629  Rhcrbcg8HBw  sustainability, economics, biosphere, social c...
# 630  L-q-tSHo9Ho  brain, humanity, sex, society, physiology, sex...
# 631  -guHd9Zrbn4                         live music, singer, vocals
# 632  vVx39Jv6PFM  parenting, society, tedx, gender spectrum, tra...
# 633  c0bsKc4tiuY  design, funny, personal growth, robots, techno...
# 634  EZKDkSY1GBM  entrepreneur, architecture, urban planning, ga...
# 635  phu4Z6QEXJE  community, activism, united states, violence, ...
# 636  Bs2Fv3YiSFM  communication, community, race, leadership, in...
# 637  pVeq-0dIqpk  social change, communication, leadership, work...
# 638  g3vSYbT1Aco  self, humanity, tedx, sound, speech, hearing, ...
# 639  eemOZfsrKdg  invention, innovation, health, health care, af...
# 640  3-UcGCnJ14c  united states, law, society, ted fellows, gove...
# 641  7MHOk7qVhYs  innovation, social change, health, biology, me...
# 642  F2XPF6rQ6fs  business, entrepreneur, education, innovation,...
# 643  yCm9Ng0bbEQ  history, statistics, peace, war, happiness, po...
# 644  waVUm5bhLbg  personal growth, empathy, society, internet, b...
# 645  1XvLEhZIAVk                             dance, performance art
# 646  TfKpvpxdNz8  parenting, children, personal growth, humanity...
# 647  yF4MgSh7VO4  disease, health, illness, personal growth, wor...
# 648  JoUZ929qoLk  leadership, inequality, personal growth, women...
#
#                                                  title
# 0               The language of being human | Poet Ali
# 1    Crisis support for the world, one text away | ...
# 2    A global pandemic calls for global solutions |...
# 3    How to shift your mindset and choose your futu...
# 4           An ode to living on Earth | Oliver Jeffers
# 5    What's missing from the American immigrant nar...
# 6    How to co-parent as allies, not adversaries | ...
# 7    The dangers of a noisy ocean -- and how we can...
# 8    Spectacular, glorious, musical wizardry | Jaco...
# 9    Racism has a cost for everyone | Heather C. Mc...
# 10   How to spark your curiosity, scientifically | ...
# 11   How the coronavirus pandemic is changing the w...
# 12   How the coronavirus is impacting India -- and ...
# 13   What coronavirus means for the global economy ...
# 14   A global hackathon to take on the coronavirus ...
# 15   The wonders of the molecular world, animated |...
# 16   The galactic recipe for a living planet | Kari...
# 17   How understanding divorce can help your marria...
# 18   How health workers are responding to the COVID...
# 19   An ethical plan for ending the pandemic and re...
# 20   It's OK to feel overwhelmed. Here's what to do...
# 21   In uncertain times, think like a mother | Yifa...
# 22   Why sleep matters now more than ever | Matt Wa...
# 23    The intangible effects of walls | Alexandra Auer
# 24   What it's really like to have autism | Ethan Lisi
# 25   How to make pandemics optional, not inevitable...
# 26   How you can help save the monarch butterfly --...
# 27   How we can navigate the pandemic with courage ...
# 28   How forgiveness can create a more just legal s...
# 29   How to create meaningful connections while apa...
# ..                                                 ...
# 619     How I made friends with reality | Emily Levine
# 620  The shocking danger of mountaintop removal -- ...
# 621  What it's like to be the child of immigrants |...
# 622  Where joy hides and how to find it | Ingrid Fe...
# 623                      'You Found Me' | Helen Gillet
# 624  Why fascism is so tempting -- and how your dat...
# 625  How Pakistani women are taking the internet ba...
# 626  The age-old sharing economies of Africa -- and...
# 627  Scientists must be free to learn, to speak and...
# 628  The doctors, nurses and aid workers rebuilding...
# 629  A healthy economy should be designed to thrive...
# 630   The truth about unwanted arousal | Emily Nagoski
# 631            'Iyeza' / 'Zabalaza' | Thandiswa Mazwai
# 632  What it's like to be a transgender dad | LB Ha...
# 633  Why you should make useless things | Simone Gi...
# 634  A playful solution to the housing crisis | Sar...
# 635  How Baltimore called a ceasefire | Erricka Bri...
# 636  What it takes to be racially literate | Priya ...
# 637    How to build (and rebuild) trust | Frances Frei
# 638  Why you donâ€™t like the sound of your own voi...
# 639  To design better tech, understand context | Ta...
# 640  It's time for the law to protect victims of ge...
# 641  How a male contraceptive pill could work | Joh...
# 642      Why tech needs the humanities | Eric Berridge
# 643  Is the world getting better or worse? A look a...
# 644          Empathy is not endorsement | Dylan Marron
# 645        'RainMakers' | Qudus Onikeku and The QTribe
# 646  What I've learned about parenting as a stay-at...
# 647  How work kept me going during my cancer treatm...
# 648  A woman's fury holds lifetimes of wisdom | Tra...
#
# [649 rows x 3 columns]

# %%
tfidf = TfidfVectorizer(
    min_df = 5,
    max_df = 0.95,
    max_features = None,
    stop_words = 'english'
)
tfidf.fit(data.tags)
text = tfidf.transform(data.tags)

# %%
text
# Out:
# <649x205 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4273 stored elements in Compressed Sparse Row format>

# %%
def find_optimal_clusters(data, max_k):
    iters = range(2, max_k+1, 2)
    
    sse = []
    for k in iters:
        sse.append(MiniBatchKMeans(n_clusters=k, init_size=None, batch_size=2, random_state=20).fit(data).inertia_)
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='o')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')
    
find_optimal_clusters(text, 50)
# Out:
# Fit 2 clusters
# Fit 4 clusters
# Fit 6 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=8. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=8. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=8. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=10. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=10. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=10. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=12. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=12. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=12. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=14. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=14. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=14. Setting it to 3*k
#   init_size=init_size)
# Fit 8 clusters
# Fit 10 clusters
# Fit 12 clusters
# Fit 14 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=16. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=16. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=16. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=18. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=18. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=18. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=20. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=20. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=20. Setting it to 3*k
#   init_size=init_size)
# Fit 16 clusters
# Fit 18 clusters
# Fit 20 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=22. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=22. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=22. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=24. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=24. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=24. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=26. Setting it to 3*k
#   init_size=init_size)
# Fit 22 clusters
# Fit 24 clusters
# Fit 26 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=26. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=26. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=28. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=28. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=28. Setting it to 3*k
#   init_size=init_size)
# Fit 28 clusters
# Fit 30 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=30. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=30. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=30. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=32. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=32. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=32. Setting it to 3*k
#   init_size=init_size)
# Fit 32 clusters
# Fit 34 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=34. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=34. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=34. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=36. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=36. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=36. Setting it to 3*k
#   init_size=init_size)
# Fit 36 clusters
# Fit 38 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=38. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=38. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=38. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=40. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=40. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=40. Setting it to 3*k
#   init_size=init_size)
# Fit 40 clusters
# Fit 42 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=42. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=42. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=42. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=44. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=44. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=44. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=46. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=46. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=46. Setting it to 3*k
#   init_size=init_size)
# Fit 44 clusters
# Fit 46 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=48. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=48. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=48. Setting it to 3*k
#   init_size=init_size)
# Fit 48 clusters
# Fit 50 clusters
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=50. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=50. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=50. Setting it to 3*k
#   init_size=init_size)

# %%
clusters = MiniBatchKMeans(n_clusters=20, init_size=None, batch_size=2, random_state=20).fit_predict(text)
# Out:
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=20. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=20. Setting it to 3*k
#   init_size=init_size)
# C:\Users\heyiz\anaconda3\envs\pytorchenv\lib\site-packages\sklearn\cluster\k_means_.py:1559: RuntimeWarning: init_size=6 should be larger than k=20. Setting it to 3*k
#   init_size=init_size)

# %%
def plot_tsne_pca(data, labels):
    max_label = max(labels)
#     max_items = np.random.choice(range(data.shape[0]), size=3000, replace=False)
    max_items = np.random.choice(range(data.shape[0]), size=649, replace=False)
        
    pca = PCA().fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA().fit_transform(data[max_items,:].todense()))
    
#     idx = np.random.choice(range(pca.shape[0]), size=300, replace=False)
    idx = np.random.choice(range(pca.shape[0]), size=649, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %%
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(), 4)
# Out:
# Cluster 0
# technology,tedx,invention,physics
#
# Cluster 1
# equality,youth,money,trust
#
# Cluster 2
# discovery,cosmos,space,solar
#
# Cluster 3
# genetics,molecular,imaging,medical
#
# Cluster 4
# culture,history,work,productivity
#
# Cluster 5
# politics,society,change,social
#
# Cluster 6
# medical,care,disease,illness
#
# Cluster 7
# entertainment,vocals,art,performance
#
# Cluster 8
# states,united,tedmed,poverty
#
# Cluster 9
# growth,success,personal,potential
#
# Cluster 10
# medicine,health,medical,research
#
# Cluster 11
# communication,growth,personal,success
#
# Cluster 12
# education,empathy,mental,compassion
#
# Cluster 13
# crime,law,criminal,justice
#
# Cluster 14
# technology,data,development,privacy
#
# Cluster 15
# innovation,storytelling,writing,creativity
#
# Cluster 16
# body,brain,science,neuroscience
#
# Cluster 18
# medicine,public,care,health
#
# Cluster 19
# technology,change,society,humanity
